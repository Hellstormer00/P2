# %%
DATA = '/Users/Alex/P2/EBauelemente/Data'
PLOTS = '/Users/Alex/P2/EBauelemente/Plots'

U = 2  # V

def rotate_labels(plot):
    for item in plot.get_xticklabels():
        item.set_rotation(45)
        
def to_log(data):
    data["R/Ohm [log10]"] = np.log10(data["R/Ohm"])

def to_log2(data):
    data["R/Ohm [log2]"] = np.log2(data["R/Ohm"])

sns.set_style("whitegrid")

ntc = pd.read_csv(os.path.join(DATA, "NTC.txt"), delim_whitespace=True)
pt = pd.read_csv(os.path.join(DATA, "PT100.txt"), delim_whitespace=True)
pt.head(3)
# Out:
#    T/C  R/Ohm
# 0   22    910
# 1   30    930
# 2   40    950

# %%
to_log(ntc)
p = sns.regplot(x="T/C", y="R/Ohm [log10]", data=ntc)
rotate_labels(p)
plt.savefig(os.path.join(PLOTS, "ntc_plot.png"))

# %%
p = sns.regplot(x="T/C", y="R/Ohm", data=pt)
rotate_labels(p)
plt.savefig(os.path.join(PLOTS, "pt100_plot.png"))

# %%
# Calculations
# ntc["R(T)*T / Ohm*C"] = ntc["R/Ohm [log10]"]*ntc["T/C"]
ntc["1/T"] = 1/ntc["T/C"]
to_log2(ntc)
p = sns.regplot(x="1/T", y="R/Ohm [log2]", data=ntc)
rotate_labels(p)
plt.savefig(os.path.join(PLOTS, "ntc_plot_fit.png"))
