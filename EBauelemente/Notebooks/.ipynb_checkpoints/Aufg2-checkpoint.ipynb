# %%
data = pd.read_csv("../Data/Aufg2.csv")
PLOTS = "../Plots"
sns.set_style("whitegrid")

# %%
p = sns.barplot(x="Element", y="U/V", data=data)
for item in p.get_xticklabels():
    item.set_rotation(45)
plt.savefig("../Plots/Aufg2_plot", dpi=300)
