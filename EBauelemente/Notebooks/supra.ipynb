# %%
CWD = "/Users/alex/Praktikum/EBauelemente"
data = pd.read_csv(os.path.join(CWD, "Data/Supra.csv"))
sns.set_style("whitegrid")
data = data.astype('float')
data.head()
# Out:
#     T/K    U/V
# 0   0.0  0.170
# 1  -5.0  0.166
# 2 -10.0  0.164
# 3 -15.0  0.162
# 4 -20.0  0.160

# %%
data["T/K"] += 273

# %%
p = sns.scatterplot(x="T/K", y="U/V", data=data)
for item in p.get_xticklabels():
    item.set_rotation(45)
plt.savefig(os.path.join(CWD, "Plots/Supra_plot"), dpi=300)

# %%
I = 0.063  # mA
data["I/mA"] = data["U/V"] / I
p = sns.scatterplot(x="T/K", y="I/mA", data=data)
for item in p.get_xticklabels():
    item.set_rotation(45)
plt.savefig(os.path.join(CWD, "Plots/Supra_plot"), dpi=300)
