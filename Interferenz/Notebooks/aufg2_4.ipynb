# %%
import os
DIR = os.path.abspath('')
DATA = os.path.join(DIR, '../Data')
PLOTS = os.path.join(DIR, '../Plots')

sns.set_style('whitegrid')

def to_degree(min):
    return min/60

data = pd.read_csv(os.path.join(DATA, 'aufg2_4.csv'), comment='#', engine='python')
data['alpha[deg]'] = -(data['deg'] + to_degree(data['min']))
data['alpha[deg]'][:8] *= -1
data
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#           Farbe   deg  min  alpha[deg]
# 0   Dunkel-Blau  16.0    8   16.133333
# 1          Blau  16.5   20   16.833333
# 2     Hell-Blau  17.0    2   17.033333
# 3           Rot  22.0   29   22.483333
# 4   Dunkel-Blau  34.0    5   34.083333
# 5          Blau  34.5    0   34.500000
# 6     Hell-Blau  35.0   15   35.250000
# 7           Rot  49.0   12   49.200000
# 8   Dunkel-Blau  16.5    8  -16.633333
# 9          Blau  17.0   19  -17.316667
# 10    Hell-Blau  17.5    4  -17.566667
# 11          Rot  23.0    4  -23.066667
# 12  Dunkel-Blau  35.0   21  -35.350000
# 13         Blau  35.5    5  -35.583333
# 14    Hell-Blau  36.0    2  -36.033333
# ...

# %%
alpha_rot = data['alpha[deg]'][data['Farbe'] == 'Rot']
alpha_hell = data['alpha[deg]'][data['Farbe'] == 'Hell-Blau']
alpha_blau = data['alpha[deg]'][data['Farbe'] == 'Blau']
alpha_dunkel = data['alpha[deg]'][data['Farbe'] == 'Dunkel-Blau']
